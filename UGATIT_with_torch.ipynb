# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/a_sharma/UGATIT_pytorch
# Out:
# /content/drive/My Drive/a_sharma/UGATIT_pytorch

# %%
# !git clone https://github.com/znxlwm/UGATIT-pytorch.git
# Out:
# Cloning into 'UGATIT-pytorch'...
# remote: Enumerating objects: 70, done.
# remote: Total 70 (delta 0), reused 0 (delta 0), pack-reused 70
# Unpacking objects: 100% (70/70), done.

# %%
cd UGATIT-pytorch/
# Out:
# /content/drive/My Drive/a_sharma/UGATIT_pytorch/UGATIT-pytorch

# %%
# !python main.py --dataset face2anime
# Out:
# number of epochs must be larger than or equal to one
#
# ##### Information #####
# # light :  False
# # dataset :  face2anime
# # batch_size :  1
# # iteration per epoch :  1000000
#
# ##### Generator #####
# # residual blocks :  4
#
# ##### Discriminator #####
# # discriminator layer :  6
#
# ##### Weight #####
# # adv_weight :  1
# # cycle_weight :  10
# # identity_weight :  10
# # cam_weight :  1000
# tcmalloc: large alloc 1073741824 bytes == 0x50a6000 @  0x7f9f7b591b6b 0x7f9f7b5b1379 0x7f9f24d0db4a 0x7f9f24d0f5fa 0x7f9f2703f78a 0x7f9f2728830b 0x7f9f272cfb37 0x7f9f70156ad5 0x7f9f7015717b 0x7f9f7015b160 0x7f9f6ffa8496 0x551b15 0x5aa6ec 0x50abb3 0x50c5b9 0x508245 0x509642 0x595311 0x54a6ff 0x551b81 0x5aa6ec 0x50abb3 0x50d390 0x508245 0x509642 0x595311 0x54a6ff 0x551b81 0x5aa6ec 0x50abb3 0x50d390
# training start !
# Traceback (most recent call last):
#   File "main.py", line 83, in <module>
#     main()
#   File "main.py", line 75, in main
#     gan.train()
# ...
